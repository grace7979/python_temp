# %% [markdown]
# ## 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
size = 100

# %%
y=np.random.standard_normal(size)
x=range(size)
plt.plot(x,y,"b", lw=2)

# %%
y=np.random.standard_normal(size)
x=range(size)
plt.plot(x,y,"o",)

# %%
y=np.random.standard_normal(size)
x=range(size)
plt.plot(x,y,"v",)

# %%
plt.title("Test Saple")
# Out:
# Text(0.5,1,'Test Saple')

# %%
y=np.linspace(1,10,10)
x=np.linspace(1,30,10)
plt.plot(x,y,"b--")
plt.xlim(2,3)
plt.ylim(0,10)
# Out:
# (0, 10)

# %% [markdown]
# ## scatter 플랫은 3개의 값을 가지고 표현할때eg: 수학, 국어, 분류

# %%
tips = sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c8bcbf89f996> in <module>()
# ----> 1 tips = sns.load_dataset("tips")
#
# NameError: name 'sns' is not defined
